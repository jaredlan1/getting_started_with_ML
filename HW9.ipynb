# %% [markdown]
# <a href="https://colab.research.google.com/github/jaredlan1/getting_started_with_ML/blob/main/HW9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q torch-geometric scipy matplotlib

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from scipy.integrate import solve_ivp

from torch_geometric.data import Data

from torch_geometric.loader import DataLoader


from torch_geometric.utils import scatter

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

# %%
DATA_PATH = "/content/drive/MyDrive/Physics Informed ML/HW/pysr_data_set.csv"

raw_data = np.load(DATA_PATH, allow_pickle=True)
print("keys:", raw_data.files)
print("shapes:", {k: raw_data[k].shape for k in raw_data.files})

X_train_np = raw_data["X_train"].astype(np.float32)
y_train_np = raw_data["y_train"].astype(np.float32)
X_test_np  = raw_data["X_test"].astype(np.float32)
y_test_np  = raw_data["y_test"].astype(np.float32)
times_np   = raw_data["times"].astype(np.float32)

nt = len(times_np)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     492             try:
# --> 493                 return pickle.load(fid, **pickle_kwargs)
#     494             except Exception as e:
#
# UnpicklingError: invalid load key, '5'.
#
# The above exception was the direct cause of the following exception:
#
# UnpicklingError                           Traceback (most recent call last)
# /tmp/ipykernel_4774/419294294.py in <cell line: 0>()
#       1 DATA_PATH = "/content/drive/MyDrive/Physics Informed ML/HW/pysr_data_set.csv"
#       2
# ----> 3 raw_data = np.load(DATA_PATH, allow_pickle=True)
#       4 print("keys:", raw_data.files)
#       5 print("shapes:", {k: raw_data[k].shape for k in raw_data.files})
#
# ...
